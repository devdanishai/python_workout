# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/chap002.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# - title()
# - lower()
# - upper()
# - strip(), rstrip(), lstrip()
# - \n, \t

# %%
x = "hello world"
print(x)
# Out:
# hello world

# %%
x = 'hello world'
x = 'hello world from python'
print(x)
# Out:
# hello world from python

# %%
name = 'will smith'
print(name.title())
name = 'Will Smith'
print(name.upper())
print(name.lower())
# Out:
# Will Smith
# WILL SMITH
# will smith

# %% [markdown]
# ### Using Variables in Strings

# %%
f_name = 'will'
l_name = 'smith'
full_name = f'{f_name} {l_name}'
print(full_name.title())
# Out:
# Will Smith

# %% [markdown]
# ### Adding Whitespace to Strings with Tabs or Newlines

# %%
print('python')
print('\tpython')
print("Languages:\nPython\nC\nJavaScript")
# Out:
# python
# 	python
# Languages:
# Python
# C
# JavaScript

# %% [markdown]
# ### Stripping Whitespace

# %%
fav_lan = 'python   '
print(fav_lan)

print(fav_lan.rstrip())
# Out:
# python
# python

# %%
fav_lan = '    python'
print(fav_lan)
print(fav_lan.lstrip())
fav_lan = '    python    '
print(fav_lan)
print(fav_lan.strip())
# Out:
#     python
# python
#     python
# python

# %% [markdown]
# ### Avoiding Syntax Errors with Strings

# %%
message = 'One of Python's strengths is its diverse community.'
print(message)
# Out:
#   File "/tmp/ipykernel_462/1631466960.py", line 1
#     message = 'One of Python's strengths is its diverse community.'
#                                                                   ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
message = "One of Python's strengths is its diverse community."
print(message)
# Out:
# One of Python's strengths is its diverse community.

# %% [markdown]
# 2-3. Personal Message: Use a variable to represent a person’s name, and print
# a message to that person. Your message should be simple, such as, “Hello Eric,
# would you like to learn some Python today?”

# %%
name = 'eric'
print(f"Hello {name.title()}, would you like to learn some Python today?")
# Out:
# Hello Eric, would you like to learn some Python today?

# %% [markdown]
# 2-4. Name Cases: Use a variable to represent a person’s name, and then print
# that person’s name in lowercase, uppercase, and title case.

# %%
name = 'eric'
print(name.upper())
print(name.lower())
print(name.title())
# Out:
# ERIC
# eric
# Eric

# %% [markdown]
# 2-5. Famous Quote: Find a quote from a famous person you admire. Print the
# quote and the name of its author. Your output should look something like the
# following, including the quotation marks:
#
# Albert Einstein once said, “A person who never made a
# mistake never tried anything new.”

# %%
print(" Marcus Tullius Cicero once said:")
print('\t"A room without books is like a body without a soul."')
# Out:
#  Marcus Tullius Cicero once said:
# 	"A room without books is like a body without a soul."

# %%
quote = "A room without books is like a body without a soul."
print(f"\tMarcus Tullius Cicero once said, \"{quote}\"")
# Out:
# 	Marcus Tullius Cicero once said, "A room without books is like a body without a soul."

# %% [markdown]
# 2-6. Famous Quote 2: Repeat Exercise 2-5, but this time, represent the
# famous person’s name using a variable called famous_person. Then compose
# your ­message and represent it with a new variable called message. Print your
# message

# %%
famous_person = "Marcus Tullius Cicero"
quote = "A room without books is like a body without a soul."

message = f"{famous_person} once said, \"{quote}\""

print(message)
# Out:
# Marcus Tullius Cicero once said, "A room without books is like a body without a soul."

# %% [markdown]
# 2-7. Stripping Names: Use a variable to represent a person’s name, and include
# some whitespace characters at the beginning and end of the name. Make sure
# you use each character combination, "\t" and "\n", at least once.
#
# Print the name once, so the whitespace around the name is displayed.
# Then print the name using each of the three stripping functions, lstrip(),
# rstrip(), and strip()

# %%
name = '\t   Will Smith   \n'

print(name)              # ✅ show original, whitespace and all
print(name.lstrip())      # removes leading whitespace only
print(name.rstrip())      # removes trailing whitespace only
print(name.strip())       # removes both
# Out:
# 	   Will Smith
#
# Will Smith
#
# 	   Will Smith
# Will Smith

# %% [markdown]
# 2-8. Number Eight: Write addition, subtraction, multiplication, and division
# operations that each result in the number 8. Be sure to enclose your operations
# in print() calls to see the results. You should create four lines that look like this:

# %%
print(4 + 4)
print(12 - 4)
print(2 * 4)
print(16 // 2)
# Out:
# 8
# 8
# 8
# 8

# %% [markdown]
# 2-9. Favorite Number: Use a variable to represent your favorite number. Then,
# using that variable, create a message that reveals your favorite number. Print
# that message

# %%
fav_num = 8
print(f"my favourite number is {fav_num}")
# Out:
# my favourite number is 8

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
