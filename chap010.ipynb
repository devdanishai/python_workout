# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/chap010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Reading from a File
#     1. reading content
#     2. relative and absolute paths
#     3. Accessing a File’s Lines
#     4. Working with a File’s Contents
#     5. Large Files: One Million Digits
#     6. Is Your Birthday Contained in Pi?
# 2. writing content
#     1. writing single line
#     2. writing multiple lines

# %%
# !pwd
# Out:
# /content

# %%
# !ls
# Out:
# sample_data

# %%
# !touch pi.txt

# %%
from pathlib import Path
path = Path('pi_digits.txt')
contents = path.read_text()
print(contents)
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %%
# 1. reading content
from pathlib import Path
path = Path('pi_digits.txt')
contents = path.read_text()
print(contents)
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %%
# !pwd
# Out:
# /content

# %%
# 2. abdolute and relative path
from pathlib import Path
# path = Path('pi_digits.txt')
path = Path('/content/pi_digits.txt')
contents = path.read_text()
print(contents)
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %%
# 3. Accessing a File’s Lines
from pathlib import Path
path = Path('pi_digits.txt')
contents = path.read_text()
lines = contents.splitlines()
for line in lines:
  print(line)
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %%
# example of 3
'''hello.txt
Hello
World
python
'''
from pathlib import Path
path = Path('hello.txt')
contents = path.read_text()
print(contents)
lines = contents.splitlines()
print(lines)
# Out:
# Hello
# World
# Python
# ['Hello', 'World', 'Python']

# %%
# 4. Working with a File’s Contents
from pathlib import Path
path = Path('pi_digits.txt')
contents = path.read_text()
lines = contents.splitlines()
print(lines)

pi_string = ''
for line in lines:
  pi_string += line

print(pi_string)
print(len(pi_string))
# Out:
# ['3.1415926535', '8979323846', '2643383279']
# 3.141592653589793238462643383279
# 32

# %% [markdown]
# 10-1. Learning Python: Open a blank file in your text editor and write a
# few lines summarizing what you’ve learned about Python so far. Start each
# line with the phrase In Python you can. . . . Save the file as
# learning_python.txt in the same directory as your exercises from this
# chapter. Write a program that reads the file and prints what you wrote two
# times: print the contents once by reading in the entire file, and once by
# storing the lines in a list and then looping over each line.

# %%
# !touch learning_python.txt

# %%
#make learning_python add following in that file
# In python we can do data manupulation
# In python we can create backends

# %%
from pathlib import Path
path = Path("learning_python.txt")
contents = path.read_text()
print(contents)
# Out:
# In python we can do data manupulation
# In python we can create backends

# %%
from pathlib import Path
path = Path("learning_python.txt")
contents = path.read_text()
lines = contents.splitlines()

for line in lines:
  print(line)
# Out:
# In python we can do data manupulation
# In python we can create backends

# %% [markdown]
# 10-2. Learning C: You can use the replace() method to replace any word in
# a string with a different word. Here’s a quick example showing how to
# replace 'dog' with 'cat' in a sentence:
# >>> message = "I really like dogs."
# >>> message.replace('dog', 'cat')
# 'I really like cats.'
# Read in each line from the file you just created, learning_python.txt, and
# replace the word Python with the name of another language, such as C. Print
# each modified line to the screen.

# %%
from pathlib import Path

path = Path("learning_python.txt")
content = path.read_text()
new_content = content.replace('python','java')
print(new_content)
# Out:
# In java we can do data manupulation
# In java we can create backends

# %% [markdown]
# 10-3. Simpler Code: The program file_reader.py in this section uses a
# temporary variable, lines, to show how splitlines() works. You can skip the
# temporary variable and loop directly over the list that splitlines() returns:\
# for line in contents.splitlines():\
# Remove the temporary variable from each of the programs in this section,
# to make them more concise.

# %%
# !touch pi_digits.txt

# %%
from pathlib import Path

path = Path('pi_digits.txt')

contents = path.read_text()

for i in contents.splitlines():
  print(i)
# Out:
# 3.1415926535
# 8979323846
# 2643383279

# %% [markdown]
# ---

# %% [markdown]
# # Writing file

# %%
from pathlib import Path
path = Path('programming.txt')
path.write_text("I love programming.")
# Out:
# 19

# %%
# my note
# write content in existing file
with open("programming.txt", "a") as file:
    file.write("\nI also love learning Java.")

# %%
# my practise
from pathlib import Path

path = Path('myfile.txt')
path.write_text('i am writing text in myfile')

print(path.read_text())
contents = path.read_text()
#print(contents)
# Out:
# i am writing text in myfile

# %%
# writing multiple lines in file
from pathlib import Path
contents = "I love programming.\n"
contents += "I love creating new games.\n"
contents += "I also love working with data.\n"
path = Path('programming.txt')
path.write_text(contents)
# Out:
# 78

# %% [markdown]
# ---

# %% [markdown]
# 10-4. Guest: Write a program that prompts the user for their name. When
# they respond, write their name to a file called guest.txt.

# %%
user = input("enter your name: ")
from pathlib import Path
path = Path('guest.txt')
path.write_text(user)
# Out:
# enter your name: ali
# 3

# %% [markdown]
# 10-5. Guest Book: Write a while loop that prompts users for their name.
# Collect all the names that are entered, and then write these names to a file
# called guest_book.txt. Make sure each entry appears on a new line in the
# file.

# %%
from pathlib import Path

names = ""

while True:
  user = input("enter name or q for exit: ")
  if user == 'q':
    break
  else:
    names += user + '\n'

path = Path('guestbook.txt')
path.write_text(names)
print(path.read_text())
# Out:
# enter name or q for exit: ali
# enter name or q for exit: wali
# enter name or q for exit: sami
# enter name or q for exit: shami
# enter name or q for exit: q
# ali
# wali
# sami
# shami

# %% [markdown]
# ---

# %% [markdown]
# # Exceptions

# %%
# Handling the ZeroDivisionError Exception
print(5/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_1261/1152173066.py in <cell line: 0>()
# ----> 1 print(5/0)
#
# ZeroDivisionError: division by zero

# %%
# Using try-except Blocks
try:
  print(5/0)
except ZeroDivisionError:
  print("You can't divide by zero!")
# Out:
# You can't divide by zero!

# %%
print("Give me two numbers, and I'll divide them.")
print("Enter 'q' to quit.")
while True:

  first_number = input("\nFirst number: ")
  if first_number == 'q':
    break

  second_number = input("Second number: ")
  if second_number == 'q':
    break

  try:
    answer = int(first_number) / int(second_number)
  except ZeroDivisionError:
    print("You can't divide by 0!")
  else:
   print(answer)
# Out:
# Give me two numbers, and I'll divide them.
# Enter 'q' to quit.
#
# First number: 5
# Second number: 4
# 1.25
#
# First number: q

# %%
try:
  age = int(input("enter your age"))
except ValueError:
  print('do not enter desimels')
else:
  print(age)
# Out:
# enter your age5
# 5

# %%
print("enter 2 numbers i will devide them")
print("enter q for exit")

while True:
  first_num = input("enter First number: ")
  if first_num == 'q':
    break

  second_num = input("enter 2nd number: ")
  if second_num == 'q':
    break

  try:
    answer = int(first_num) / int(second_num)
  except ZeroDivisionError:
    print("cant devide by zero")
  else:
    print(answer)
# Out:
# enter 2 numbers i will devide them
# enter q for exit
# enter First number: 5
# enter 2nd number: 5
# enter First number: q
# 1.0

# %%
from pathlib import Path
path = Path('alice.txt')
contents = path.read_text(encoding='utf-8')
print(contents[:200])
# Out:
# ﻿The Project Gutenberg eBook of Alice’s Adventures in Wonderland, by Lewis Carroll
#
# This eBook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and w

# %%
from pathlib import Path
path = Path('alice1.txt')
try:
  contents = path.read_text(encoding='utf-8')
  print(contents[:200])
except FileNotFoundError:
  print(f"Sorry, the file {path} does not exist.")
# Out:
# Sorry, the file alice1.txt does not exist.

# %%
# text analysis
from pathlib import Path
path = Path('alice.txt')
try:
  contents = path.read_text(encoding='utf-8')
except FileNotFoundError:
  print(f"Sorry, the file {path} does not exist.")
else:
# Count the approximate number of words in the file:

  words = contents.split()

  num_words = len(words)
  print(f"The file {path} has about {num_words} words.")
# Out:
# The file alice.txt has about 29594 words.
