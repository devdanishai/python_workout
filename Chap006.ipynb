# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/Chap006.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Working on dict:
# - create dict
# - access values
# - update dict
# - create empty dict
# - del value
# - Using get() to Access Values
#
# 2. Loop on dict:
# - for i in dict: # it also print keys
# - for k, v in dict.items()
# - for name in dict.keys():
# - for v in dict.values():
# - comapre list with dict
#     ```bash
#     for i in list:
#         if i in dict:
#     ```
# 3. Nesting:
# - A List of Dictionaries
# - create dict with for loop(range).
# - A List in a Dictionary
# - A Dictionary in a Dictionary

# %%
# user1 = {'name': 'ali', 'grade': '5', 'subject': 'science'}


# #user1['name'] = 'ahmed'
# print(user1['name'])

# user2 = {}
# user2['name'] = 'ahmed'
# user2['grade'] = '5'
# user2['subject'] = 'arts'
# print(user2)

#del value
# alien_0 = {'color': 'green', 'points': 5}
# print(alien_0)
# del alien_0['points']
# print(alien_0)

# Using get() to Access Values
alien_0 = {'color': 'green', 'speed': 'slow'}
point_value = alien_0.get('points', 'No point value assigned.')
print(point_value)
print(alien_0)
'''If there’s a chance the key you’re asking for might not exist, consider
using the get() method instead of the square bracket notation.'''
# Out:
# No point value assigned.
# {'color': 'green', 'speed': 'slow'}

# %%
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}
for name, language in favorite_languages.items():
  print(f"{name.title()}'s favorite language is {language.title()}.")
# Out:
# Jen's favorite language is Python.
# Sarah's favorite language is C.
# Edward's favorite language is Ruby.
# Phil's favorite language is Python.

# %%
# Looping Through All the Keys in a Dictionary
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}
for name in favorite_languages.keys():
  print(name.title())
# Out:
# Jen
# Sarah
# Edward
# Phil

# %%
friends = ['phil', 'sarah']
for name in favorite_languages.keys():
  print(name.title())

if name in friends:
  language = favorite_languages[name].title()
  print(f"\t{name.title()}, I see you love {language}!")
# Out:
# Jen
# Sarah
# Edward
# Phil
# 	Phil, I see you love Python!

# %%
# practise
# Looping Through All the Keys in a Dictionary
fav_lang = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}

friends1 = ['phil', 'sarah']
for i in fav_lang:
  print(i.title())

if i in friends1:
  language = fav_lang[name].title()
  print(f"{i.title()}, u like {language}! ")
# Out:
# Jen
# Sarah
# Edward
# Phil
# Phil, u like Python!

# %%
fav_lang1 = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}

if 'erin' not in fav_lang1.keys:
  print("erin tool pat in poll")
# Out:
# erin tool pat in poll

# %% [markdown]
# ## Looping Through a Dictionary’s Keys in a Particular Order

# %%
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}
for name in sorted(favorite_languages.keys()):
  print(f"{name.title()}, thank you for taking the poll.")
# Out:
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.

# %%
# practise
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}
for name in sorted(favorite_languages.keys()):
  print(f"{name.title()}, thank you for taking the poll.")
# Out:
# Edward, thank you for taking the poll.
# Jen, thank you for taking the poll.
# Phil, thank you for taking the poll.
# Sarah, thank you for taking the poll.

# %% [markdown]
# ## Looping Through All Values in a Dictionary

# %%
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}

for language in favorite_languages.values():
  print(f"polling languages include : {language}")
# Out:
# polling languages include : python
# polling languages include : c
# polling languages include : ruby
# polling languages include : python

# %%
# check each language without duplication
favorite_languages = {
'jen': 'python',
'sarah': 'c',
'edward': 'ruby',
'phil': 'python',
}
print("The following languages have been mentioned:")
for language in set(favorite_languages.values()):
  print(language.title())
# Out:
# The following languages have been mentioned:
# C
# Python
# Ruby

# %%
# set() : practise

fav_books = {'ali': 'python course', 'sarah': 'python course', 'wali': 'java course', 'hadi': 'html course'}

print(set(fav_books.values()))
# Out:
# {'html course', 'python course', 'java course'}

# %% [markdown]
# ## Try it

# %%
'''6-4. Glossary 2: Now that you know how to loop through a dictionary, clean
up the code from Exercise 6-3 (page 99) by replacing your series of print()
calls with a loop that runs through the dictionary’s keys and values. When
you’re sure that your loop works, add five more Python terms to your glossary.
When you run your program again, these new words and meanings should
automatically be included in the output.
'''

# %%
glossary = { 'string': 'an alphabet or group of word ', 'integer' : 'whole numbetr', 'float' : 'decimel numbers', 'set' : 'no duplicate, mutable, unordered, {}', 'list' : 'double allow, mutable, ordered, []' }
#print(glossary)

for k,v in glossary.items():
  print(f'\n{k.title()}:')
  print(f'{v.title()}.')
# Out:
# String:
# An Alphabet Or Group Of Word .
#
# Integer:
# Whole Numbetr.
#
# Float:
# Decimel Numbers.
#
# Set:
# No Duplicate, Mutable, Unordered, {}.
#
# List:
# Double Allow, Mutable, Ordered, [].

# %% [markdown]
# 6-5. Rivers: Make a dictionary containing three major rivers and the country
# each river runs through. One key-value pair might be 'nile': 'egypt'.
#
# •Use a loop to print a sentence about each river, such as The Nile runs
# through Egypt.
#
# •Use a loop to print the name of each river included in the dictionary.
#
# •Use a loop to print the name of each country included in the dictionary.

# %%
rivers = { 'indus': 'pakistan', 'gangas': 'india', 'nile' : 'egypt' }

for k,v in rivers.items():
  print(f'The {k.title()} runs through {v.title()}')

for k in rivers.keys():
  print(k.title())

for v in rivers.values():
  print(v.title())
# Out:
# The Indus runs through Pakistan
# The Ganag runs through India
# The Nile runs through Egypt
# Indus
# Ganag
# Nile
# Pakistan
# India
# Egypt

# %% [markdown]
# 6-6. Polling: Use the code in favorite_languages.py (page 97).
#
# •Make a list of people who should take the favorite languages poll. Include
# some names that are already in the dictionary and some that are not.
#
# •Loop through the list of people who should take the poll. If they have
# already taken the poll, print a message thanking them for responding.
# If they have not yet taken the poll, print a message inviting them to take
# the poll.

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}

people = ['jen', 'sarah', 'will', 'tom', 'edward']

for person in people:
    if person in favorite_languages:
        print(f"Thank you for taking the poll, {person.title()}!")
    else:
        print(f"{person.title()}, please take the favorite language poll.")
# Out:
# ['list', 'list', 'list', 'list']

# %%
favorite_languages = {
    'jen': 'python',
    'sarah': 'c',
    'edward': 'ruby',
    'phil': 'python',
}

people = ['jen', 'sarah', 'will', 'tom', 'edward']

for person in people:
  if person in favorite_languages:
    print(f"thanks for participation {person.title()}")
  else:
    print(f"{person.title()}u should take part")
# Out:
# thanks for participation Jen
# thanks for participation Sarah
# Willu should take part
# Tomu should take part
# thanks for participation Edward

# %% [markdown]
# # **Nesting**

# %% [markdown]
# ### 1. A List of Dictionaries

# %%
# aliens.py
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}
aliens = [alien_0, alien_1, alien_2]
for alien in aliens:
  print(alien)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}

# %%
# students.py
roll_no1 = {'name': 'ali', 'age': '15', 'subjec':'arts'}
roll_no2 = {'name': 'ahmed', 'age': '14', 'subjec':'science'}
roll_no3 = {'name': 'sara', 'age': '15', 'subjec':'computer'}


class_10 = [roll_no1,roll_no2,roll_no3]

for i in class_10:
  print(i)
# Out:
# {'name': 'ali', 'age': '15', 'subjec': 'arts'}
# {'name': 'ahmed', 'age': '14', 'subjec': 'science'}
# {'name': 'sara', 'age': '15', 'subjec': 'computer'}

# %%
# Make an empty list for storing aliens.
aliens = []
# Make 30 green aliens.
for alien_number in range(30):
  new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
  aliens.append(new_alien)
# Show the first 5 aliens.
for alien in aliens[:5]:
  print(alien)
  print("...")
# Show how many aliens have been created.
print(f"Total number of aliens: {len(aliens)}")

# %%
# Make an empty list for storing aliens.
aliens = []

# Make 30 green aliens.
for alien_number in range(30):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

# Change the first 3 aliens to yellow, medium speed, and 10 points.
for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)

print("...")

# %%
aliens = []

for i in range(15):
    new_alien = {'color': 'green', 'points': 5, 'speed': 'slow'}
    aliens.append(new_alien)

for alien in aliens[:3]:
    if alien['color'] == 'green':
        alien['color'] = 'yellow'
        alien['speed'] = 'medium'
        alien['points'] = 10

# Show the first 5 aliens.
for alien in aliens[:5]:
    print(alien)
# Out:
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}

# %% [markdown]
# ### 2. A List in a Dictionary

# %%
# Store information about a pizza being ordered.
pizza = {
    'crust': 'thick',
    'toppings': ['mushrooms', 'extra cheese'],
}

# Summarize the order.
print(f"You ordered a {pizza['crust']}-crust pizza with the following toppings:")

# Loop through and print each topping.
for topping in pizza['toppings']:
    print("\t" + topping)
# Out:
# You ordered a thick-crust pizza with the following toppings:
# 	mushrooms
# 	extra cheese

# %%
pizza = {
    'crust' : 'thick',
    'toppings' : ['mushroom', 'extra cheese']
}

print(f"you ordered pizza with {pizza['crust']}-crust with following toppings")

for topping in pizza['toppings']:
  print("\t" + topping)
# Out:
# you ordered pizza with thick-crust with following toppings
# 	mushroom
# 	extra cheese

# %%
favorite_languages = {
    'jen': ['python', 'ruby'],
    'sarah': ['c'],
    'edward': ['ruby', 'go'],
    'phil': ['python', 'haskell'],
}

# Loop through the dictionary items
for name, languages in favorite_languages.items():
    print("\n" + name.title() + "'s favorite languages are:")

    # Loop through the list of languages for the current person
    for language in languages:
        print("\t" + language.title())

# %%
fav_lang = {
    'ali' : ['C', 'python'],
    'sara' : ['C'],
    'wali' : ['ruby', 'python'],
    'dani' : ['python', 'java'] # Fixed the typo 'pythjon' too!
}

for name, languages in fav_lang.items():
    print(f"\n{name.title()}'s favourite languages are:")
    # Loop through the list of languages for this specific person
    for language in languages:
        print(f"\t{language.title()}")
# Out:
# Ali's favourite languages are:
# 	C
# 	Python
#
# Sara's favourite languages are:
# 	C
#
# Wali's favourite languages are:
# 	Ruby
# 	Python
#
# Dani's favourite languages are:
# 	Python
# 	Java

# %%
users = {
    'aeinstein': {
        'first': 'albert',
        'last': 'einstein',
        'location': 'princeton',
    },
    'mcurie': {
        'first': 'marie',
        'last': 'curie',
        'location': 'paris',
    },
}

for username, user_info in users.items():
    print("\nUsername: " + username)

    # All of these lines must be indented inside the loop
    full_name = user_info['first'] + " " + user_info['last']
    location = user_info['location']

    print("\tFull name: " + full_name.title())
    print("\tLocation: " + location.title())
# Out:
# Username: aeinstein
# 	Full name: Albert Einstein
# 	Location: Princeton
#
# Username: mcurie
# 	Full name: Marie Curie
# 	Location: Paris

# %%
products = {
    'p001' : {
        'product_name' : 'perfume',
        'price' : '20$',
        'status' : 'available'
    },
    'p002' : {
        'product_name' : 'body_spray',
        'price' : '15$',
        'status' : 'not_available'
    },
    'p003' : {
        'product_name' : 'body_wash',
        'price' : '12$',
        'status' : 'available'
    }
}

# print(products)

for k,v in products.items():
  print(f"product_id: {k}")

  for i,g in v.items():
    print(i,g)
# Out:
# product_id: p001
# product_name perfume
# price 20$
# status available
# product_id: p002
# product_name body_spray
# price 15$
# status not_available
# product_id: p003
# product_name body_wash
# price 12$
# status available

# %% [markdown]
# ### try it

# %% [markdown]
# 6-7. People: Start with the program you wrote for Exercise 6-1 (page 99).
# Make two new dictionaries representing different people, and store all three
# dictionaries in a list called people. Loop through your list of people. As you
# loop through the list, print everything you know about each person.

# %%
persons = {
    'person01' : {'fisrt_name' : 'ali', 'last_name' : 'khan', 'city' : 'Rwp', 'edu' : 'science'},
    'person02' : {'fisrt_name' : 'ahmed', 'last_name' : 'butt', 'city' : 'lhr', 'edu' : 'commerce'},
    'person03' : {'first_name' : 'fahad', 'last_name' : 'mustafa', 'city' : 'khr', 'edu' : 'arts'}
}

#print(persons)

for person_id, info in persons.items():
  print(person_id.title())
  for name, detail in info.items():
    print(name.title())
    print(detail.title())
# Out:
# {'person01': {'fisrt_name': 'ali', 'last_name': 'khan', 'city': 'Rwp', 'edu': 'science'}, 'person02': {'fisrt_name': 'ahmed', 'last_name': 'butt', 'city': 'lhr', 'edu': 'commerce'}, 'person03': {'first_name': 'fahad', 'last_name': 'mustafa', 'city': 'khr', 'edu': 'arts'}}
# person01
# Fisrt_Name
# Ali
# Last_Name
# Khan
# City
# Rwp
# Edu
# Science
# person02
# Fisrt_Name
# Ahmed
# Last_Name
# Butt
# City
# Lhr
# Edu
# Commerce
# person03
# First_Name
# Fahad
# Last_Name
# Mustafa
# City
# Khr
# Edu
# Arts

# %%
person01 = {'fisrt_name' : 'ali', 'last_name' : 'khan', 'city' : 'Rwp', 'edu' : 'science'}
person02 = {'fisrt_name' : 'ahmed', 'last_name' : 'butt', 'city' : 'lhr', 'edu' : 'commerce'}
person03 = {'first_name' : 'fahad', 'last_name' : 'mustafa', 'city' : 'khr', 'edu' : 'arts'}

people = [person01, person02, person03]

for i in people:
  for k,v in i.items():
    print(k)
    print(v)
  print('. . .')
# Out:
# fisrt_name
# ali
# last_name
# khan
# city
# Rwp
# edu
# science
# . . .
# fisrt_name
# ahmed
# last_name
# butt
# city
# lhr
# edu
# commerce
# . . .
# first_name
# fahad
# last_name
# mustafa
# city
# khr
# edu
# arts
# . . .

# %% [markdown]
# 6-8. Pets: Make several dictionaries, where each dictionary represents a different pet. In each dictionary, include the kind of animal and the owner’s name.
# Store these dictionaries in a list called pets. Next, loop through your list and as
# you do, print everything you know about each pet.

# %%
pet1 = { 'pet_name' : 'cat', 'food' : 'milk', 'color' : 'brown', 'owner' : 'tom'}
pet2 = { 'pet_name' : 'dog', 'food' : 'brerad', 'color' : 'black', 'owner' : 'jerry' }
pet3 = { 'pet_name' : 'rabbit', 'food' : 'carrot', 'color' : 'grey', 'owner' : 'bunny'}

pets = [pet1, pet2, pet3]


for i in pets:
  for k,v in i.items():
    print(k)
    print(v)
  print('. . .')
# Out:
# pet_name
# cat
# food
# milk
# color
# brown
# owner
# tom
# . . .
# pet_name
# dog
# food
# brerad
# color
# black
# owner
# jerry
# . . .
# pet_name
# rabbit
# food
# carrot
# color
# grey
# owner
# bunny
# . . .

# %% [markdown]
# 6-9. Favorite Places: Make a dictionary called favorite_places. Think of three
# names to use as keys in the dictionary, and store one to three favorite places
# for each person. To make this exercise a bit more interesting, ask some friends
# to name a few of their favorite places. Loop through the dictionary, and print
# each person’s name and their favorite places.

# %%
fav_places = {
    'ali' : ['lahore', 'karachi', 'islamabad'],
    'hamza' : ['karachi'],
    'zaid' : ['peshawer', 'lahore', 'multan']
    }

for k,v in fav_places.items():
  print(k,v)
# Out:
# ali ['lahore', 'karachi', 'islamabad']
# hamza ['karachi']
# zaid ['peshawer', 'lahore', 'multan']

# %% [markdown]
# 6-10. Favorite Numbers: Modify your program from Exercise 6-2 (page 99)
# so each person can have more than one favorite number. Then print each person’s name along with their favorite numbers.

# %%
fav_num = {'ali': [ 5, 6, 7], 'ahmed' : [ 4, 5, 6 ], 'dani': [ 3, 4 ], 'ammar' : [ 8, 9 ]}
print(fav_num)

for k,v in fav_num.items():
  print(f'{k} favourite numbers are:')
  for i in v:
    print(i)
  print('. . .')
# Out:
# {'ali': [5, 6, 7], 'ahmed': [4, 5, 6], 'dani': [3, 4], 'ammar': [8, 9]}
# ali favourite numbers are:
# 5
# 6
# 7
# . . .
# ahmed favourite numbers are:
# 4
# 5
# 6
# . . .
# dani favourite numbers are:
# 3
# 4
# . . .
# ammar favourite numbers are:
# 8
# 9
# . . .

# %% [markdown]
# 6-11. Cities: Make a dictionary called cities. Use the names of three cities as
# keys in your dictionary. Create a dictionary of information about each city and
# include the country that the city is in, its approximate population, and one fact
# about that city. The keys for each city’s dictionary should be something like
# country, population, and fact. Print the name of each city and all of the infor-
# mation you have stored about it.

# %%
cities = {
    'Islamabad' : { 'country' : 'pakistan', 'population' : '1 million', 'fact' : '1st planned city in the world' },
    'Istanbul' : { 'country' : 'turkey', 'population' : '2 million', 'fact' : 'famous as city of gardens' },
    'New_york' : { 'country' : 'USA', 'population' : '5 million', 'fact' : 'financial capital of USA' }
}

for k,v in cities.items():
  print(k)
  for e,i in v.items():
    print(f'{e}:')
    print(i)
  print('. . .')
# Out:
# Islamabad
# country:
# pakistan
# population:
# 1 million
# fact:
# 1st planned city in the world
# . . .
# Istanbul
# country:
# turkey
# population:
# 2 million
# fact:
# famous as city of gardens
# . . .
# New_york
# country:
# USA
# population:
# 5 million
# fact:
# financial capital of USA
# . . .

# %%
books = {
    'Ali': 'Python Crash Course',
    'Ahmed': 'Clean Code',
    'Sara': 'Atomic Habits',
    'Tom': 'Deep Work'
}

for k in books.keys():
  print(k)
# Out:
# Ali
# Ahmed
# Sara
# Tom

# %% [markdown]
# 6-1. Person: Use a dictionary to store information about a person you know.
# Store their first name, last name, age, and the city in which they live. You
# should have keys such as first_name, last_name, age, and city. Print each
# piece of information stored in your dictionary.

# %%
person = {'first_name':'ali', 'last_name': 'ahmed', 'age': '20', 'city': 'karachi'}
print(person)
# Out:
# {'first_name': 'ali', 'last_name': 'ahmed', 'age': '20', 'city': 'karachi'}

# %%
#del person['first_name']
print(person.get('first_name'))
# Out:
# None

# %% [markdown]
# 6-2. Favorite Numbers: Use a dictionary to store people’s favorite numbers.
# Think of five names, and use them as keys in your dictionary. Think of a favorite
# number for each person, and store each as a value in your dictionary. Print
# each person’s name and their favorite number. For even more fun, poll a few
# friends and get some actual data for your program

# %%
fav_num = {'ali': 5, 'ahmed': 6, 'wali': 7, 'sami': 8, 'musa': 9}
print(fav_num)
# Out:
# {'ali': 5, 'ahmed': 6, 'wali': 7, 'sami': 8, 'musa': 9}

# %% [markdown]
# 6-3. Glossary: A Python dictionary can be used to model an actual dictionary.
# However, to avoid confusion, let’s call it a glossary.\
# •Think of five programming words you’ve learned about in the previous
# chapters. Use these words as the keys in your glossary, and store their
# meanings as values.\
# •Print each word and its meaning as neatly formatted output. You might
# print the word followed by a colon and then its meaning, or print the word
# on one line and then print its meaning indented on a second line. Use the
# newline character (\n) to insert a blank line between each word-meaning
# pair in your output.

# %% [markdown]
# Cat: A small furry animal that people keep as a pet.\
# Run: To move fast on your feet.Happy: Feeling good and glad.\
# Book: A set of pages with words to read.Dog: A four-legged animal that barks and is kept as a pe

# %%
glossary = { "cat" : "a small animal", "run" : "to move fast on your feet", "happy": "good and glad", "book": "a set of pages with words to read", "dog":"a 4 legged animal that barked"}

print(glossary['dog'])
print(glossary['cat'])
print(glossary['book'])
print(glossary['happy'])
print(glossary['run'])
# Out:
# a 4 legged animal that barked
# a small animal
# a set of pages with words to read
# good and glad
# to move fast on your feet

# %%
for v in glossary.values():
  print(v)
# Out:
# a small animal
# to move fast on your feet
# good and glad
# a set of pages with words to read
# a 4 legged animal that barked

# %% [markdown]
# 6-4. Glossary 2: Now that you know how to loop through a dictionary, clean
# up the code from Exercise 6-3 (page 99) by replacing your series of print()
# calls with a loop that runs through the dictionary’s keys and values. When
# you’re sure that your loop works, add five more Python terms to your glossary.
# When you run your program again, these new words and meanings should
# automatically be included in the output.

# %%
glossary = { "cat" : "a small animal", "run" : "to move fast on your feet", "happy": "good and glad", "book": "a set of pages with words to read", "dog":"a 4 legged animal that barked"}

for k,v in glossary.items():
  print(f"\n{k}: ")
  print(f"{v}")
# Out:
# cat:
# a small animal
#
# run:
# to move fast on your feet
#
# happy:
# good and glad
#
# book:
# a set of pages with words to read
#
# dog:
# a 4 legged animal that barked

# %% [markdown]
# 6-5. Rivers: Make a dictionary containing three major rivers and the country
# each river runs through. One key-value pair might be 'nile': 'egypt'.\
# •Use a loop to print a sentence about each river, such as The Nile runs
# through Egypt.\
# •Use a loop to print the name of each river included in the dictionary.\
# •Use a loop to print the name of each country included in the dictionary.

# %%
rivers={'indus' : 'pakistan', 'ganga': 'india', 'nile': 'egypt'}

for k,v in rivers.items():
  print(f"{k.title()} through {v.title()}")

for k in rivers.keys():
  print(k)

for v in rivers.values():
  print(v)
# Out:
# Indus through Pakistan
# Ganga through India
# Nile through Egypt
# indus
# ganga
# nile
# pakistan
# india
# egypt

# %% [markdown]
# 6-6. Polling: Use the code in favorite_languages.py (page 97).\
# •Make a list of people who should take the favorite languages poll. Include
# some names that are already in the dictionary and some that are not.\
# •Loop through the list of people who should take the poll. If they have
# already taken the poll, print a message thanking them for responding.
# If they have not yet taken the poll, print a message inviting them to take
# the poll.

# %%
members = ['ali', 'wali', 'mali', 'sami', 'saad', 'harry']
fav_lan = {'ali': 'python', 'wali':'c','sami': 'java'}

for i in members:
  if i in fav_lan:
    print(f"{i} THANKS for participation" )
  else:
    print(f"{i} kindly take part in voting")
# Out:
# ali THANKS for participation
# wali THANKS for participation
# mali kindly take part in voting
# sami THANKS for participation
# saad kindly take part in voting
# harry kindly take part in voting

# %%
members = ['ali', 'wali', 'mali', 'sami', 'saad', 'harry']
v_member = ['ali', 'wali', 'sami']

for i in members:
  if i in fav_lan:
    print(f" => {i} particpated")
  else:
    print(f"{i} not participated")
# Out:
#  => ali particpated
#  => wali particpated
# mali not participated
#  => sami particpated
# saad not participated
# harry not participated

# %%
alien_0 = {'color': 'green', 'points': 5}
alien_1 = {'color': 'yellow', 'points': 10}
alien_2 = {'color': 'red', 'points': 15}
aliens = [alien_0, alien_1, alien_2]
for alien in aliens:
  print(alien)
# Out:
# {'color': 'green', 'points': 5}
# {'color': 'yellow', 'points': 10}
# {'color': 'red', 'points': 15}

# %%
aliens = []

for alien in range(30):
  alien = {'color' : 'green', 'points' : 5, 'speed': 'slow'}
  aliens.append(alien)

for alien in aliens[:3]:
  if alien['color'] == 'green':
    alien['color'] = 'yellow'
    alien['speed'] = 'medium'
    alien['points'] = 10
  elif alien['color'] == 'yellow':
    alien['color'] = 'red'
    alien['speed'] = 'fast'
    alien['points'] = 15

for alien in aliens[:5]:
  print(alien)
# Out:
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'yellow', 'points': 10, 'speed': 'medium'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}
# {'color': 'green', 'points': 5, 'speed': 'slow'}

# %% [markdown]
# 6-7. People: Start with the program you wrote for Exercise 6-1 (page 99).
# Make two new dictionaries representing different people, and store all three
# dictionaries in a list called people. Loop through your list of people. As you
# loop through the list, print everything you know about each person.

# %%
person1={'name': 'ali', 'grade':'5', 'subject':'science'}
person2={'name': 'wali', 'grade':'5', 'subject':'arts'}
person3={'name': 'sami', 'grade':'5', 'subject':'computer'}

people = [person1,person2,person3]

for i in people:
  print(i)
# Out:
# {'name': 'ali', 'grade': '5', 'subject': 'science'}
# {'name': 'wali', 'grade': '5', 'subject': 'arts'}
# {'name': 'sami', 'grade': '5', 'subject': 'computer'}

# %% [markdown]
# 6-8. Pets: Make several dictionaries, where each dictionary represents a differ-
# ent pet. In each dictionary, include the kind of animal and the owner’s name.
# Store these dictionaries in a list called pets. Next, loop through your list and as
# you do, print everything you know about each pet.

# %%
pet1 = {"name": "dog", "owner":"ali" }
pet2 = {"name":"cat","owner": "wali"}
pet3 = {"name": "turtle", "owner": "sami"}

pet=[pet1,pet2,pet3]

for i in pet:
  print(i)
# Out:
# {'name': 'dog', 'owner': 'ali'}
# {'name': 'cat', 'owner': 'wali'}
# {'name': 'turtule', 'owner': 'sami'}

# %% [markdown]
# 6-9. Favorite Places: Make a dictionary called favorite_places. Think of three
# names to use as keys in the dictionary, and store one to three favorite places
# for each person. To make this exercise a bit more interesting, ask some friends
# to name a few of their favorite places. Loop through the dictionary, and print
# each person’s name and their favorite places.

# %%
fav_places = {
    'ali':['swat', 'lahore', 'karachi'],
    'wali' :['swat', 'lahore', 'karachi'],
    'sami':['swat', 'lahore', 'karachi']
    }

# %% [markdown]
# 6-10. Favorite Numbers: Modify your program from Exercise 6-2 (page 99)
# so each person can have more than one favorite number. Then print each per-
# son’s name along with their favorite numbers

# %%
# fav_num = {'ali': 5, 'ahmed': 6, 'wali': 7, 'sami': 8, 'musa': 9}
# print(fav_num)

fav_num = {'ali': [1,2,3], 'ahmed': [4,5,6], 'wali': [7,8,9], 'sami': [1,2,3], 'musa': [9,8,7]}
print(fav_num)

for k,v in fav_num.items():
  print(f'{k}:')
  for i in v:
    print(i)
# Out:
# {'ali': [1, 2, 3], 'ahmed': [4, 5, 6], 'wali': [7, 8, 9], 'sami': [1, 2, 3], 'musa': [9, 8, 7]}
# ali:
# 1
# 2
# 3
# ahmed:
# 4
# 5
# 6
# wali:
# 7
# 8
# 9
# sami:
# 1
# 2
# 3
# musa:
# 9
# 8
# 7

# %% [markdown]
# 6-11. Cities: Make a dictionary called cities. Use the names of three cities as
# keys in your dictionary. Create a dictionary of information about each city and
# include the country that the city is in, its approximate population, and one fact
# about that city. The keys for each city’s dictionary should be something like
# country, population, and fact. Print the name of each city and all of the infor-
# mation you have stored about it

# %%
cities={'new_york': {'country':'usa', 'population': '1 million', 'fact': 'financial capital'},
        'islamabad' : { 'country':'pakistan', 'population': '8 lacks', 'fact': 'capital'},
        'istambul' : {'country': 'turkey', 'population': '2 million', 'fact': 'city of gardens'}
        }

for k,v in cities.items():
  print(f'--- city name : {k}')
  for k , v in v.items():
    print(f'=>{k}:')
    print(f'{v}.')
# Out:
# --- city name : new_york
# =>country:
# usa.
# =>population:
# 1 million.
# =>fact:
# financial capital.
# --- city name : islamabad
# =>country:
# pakistan.
# =>population:
# 8 lacks.
# =>fact:
# capital.
# --- city name : istambul
# =>country:
# turkey.
# =>population:
# 2 million.
# =>fact:
# city of gardens.

# %% [markdown]
# 6-12. Extensions: We’re now working with examples that are complex enough
# that they can be extended in any number of ways. Use one of the example pro-
# grams from this chapter, and extend it by adding new keys and values, chang-
# ing the context of the program or improving the formatting of the output.
