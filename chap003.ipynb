# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/chap003.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notes

# %% [markdown]
# 1. access element
#
# 2. modify elements
# - with elements
# - append
# - insert
#
# 3. remove element
# - del
# - pop
# - remove

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
#mc[0] = 'hero'
#mc.append('hero')
#mc.insert(4,'hero')
#del mc[0]
#mc.pop()
#mc.pop(0)
mc.remove('suzuki')

print(mc)
# Out:
# ['hero', 'honda', 'yamaha', 'suzuki', 'ducati']

# %% [markdown]
# - sort()
# - sort(reverse=True)
# - reverse()
# - sorted()
# - sorted(list_name, reverse=True)
# - len()

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
#cars.sort()
#cars.sort(reverse=True)
# cars.reverse()
#len(cars)
#print(cars)

#print(sorted(cars))
#print(sorted(places, reverse=True))

# %% [markdown]
# _____
# _____

# %% [markdown]
# # practise

# %% [markdown]
# 3-1. Names: Store the names of a few of your friends in a list called names. Print
# each person’s name by accessing each element in the list, one at a time.

# %%
names = ['ali', 'ahmed', 'zaid', 'bakar', 'tom', 'harry']
names
# Out:
# ['ali', 'ahmed', 'zaid', 'bakar', 'tom', 'harry']

# %% [markdown]
# Accessing Elements in a List

# %%
print(names[:])
print(names[0])
# Out:
# ['ali', 'ahmed', 'zaid']
# ali

# %% [markdown]
# 3-2. Greetings: Start with the list you used in Exercise 3-1, but instead of just
# printing each person’s name, print a message to them. The text of each mes-
# sage should be the same, but each message should be personalized with the
# person’s name.

# %%
names = ['ali', 'ahmed', 'zaid']

print(f"hello, {names[0]}")
print(f"hello, {names[1]}")
print(f"hello, {names[2]}")
# Out:
# hello, ali
# hello, ahmed
# hello, zaid

# %% [markdown]
# Modifying Elements in a List

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

motorcycles[0] = 'ducati'
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'yamaha', 'suzuki']

# %% [markdown]
# Appending Elements to the End of a List

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

motorcycles.append('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha', 'suzuki', 'ducati']

# %%
motorcycles = []
motorcycles.append('honda')
motorcycles.append('yamaha')
motorcycles.append('suzuki')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']

# %% [markdown]
# Inserting Elements into a List

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

motorcycles.insert(0, 'ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['ducati', 'honda', 'yamaha', 'suzuki']

# %% [markdown]
# Removing an Item Using the del Statement

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

del motorcycles[0]
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['yamaha', 'suzuki']

# %% [markdown]
# Removing an Item Using the pop() Method

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
print(motorcycles)

popped_motorcycle = motorcycles.pop()
print(motorcycles)
print(popped_motorcycle)
# Out:
# ['honda', 'yamaha', 'suzuki']
# ['honda', 'yamaha']
# suzuki

# %% [markdown]
# Popping Items from any Position in a List

# %%
motorcycles = ['honda', 'yamaha', 'suzuki']
first_owned = motorcycles.pop(0)
print(f"The first motorcycle I owned was a {first_owned.title()}.")
# Out:
# The first motorcycle I owned was a Honda.

# %% [markdown]
# Removing an Item by Value

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)

motorcycles.remove('ducati')
print(motorcycles)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']

# %%
motorcycles = ['honda', 'yamaha', 'suzuki', 'ducati']
print(motorcycles)
too_expensive = 'ducati'
motorcycles.remove(too_expensive)
print(motorcycles)
print(f"\nA {too_expensive.title()} is too expensive for me.")
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati']
# ['honda', 'yamaha', 'suzuki']
#
# A Ducati is too expensive for me.

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
mc[0]='hero'
print(mc)
# Out:
# ['hero', 'yamaha', 'suzuki', 'ducati']

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
mc.append('hero')
print(mc)
# Out:
# ['honda', 'yamaha', 'suzuki', 'ducati', 'hero']

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
print(mc)
mc.insert(0, 'ducati')
print(mc)

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
#del mc[0]
#mc.remove('honda')
#mc.pop()
last_bike= mc.pop()
print(last_bike)
print(mc)
# Out:
# ducati
# ['honda', 'yamaha', 'suzuki']

# %%
mc = ['honda', 'yamaha', 'suzuki', 'ducati']
#mc[0] = 'hero'
#mc.append('hero')
#mc.insert(4,'hero')
#del mc[0]
#mc.pop()
#mc.pop(0)
mc.remove('suzuki')

print(mc)
# Out:
# ['honda', 'yamaha', 'ducati']

# %% [markdown]
# 3-4. Guest List: If you could invite anyone, living or deceased, to dinner, who
# would you invite? Make a list that includes at least three people you’d like to
# invite to dinner. Then use your list to print a message to each person, inviting
# them to dinner.

# %%
guests = ['ali', 'sami', 'ahmed']
# for i in guests:
#   print(f"i am happy to invite you Mr.{i.title()}")

print(f"i am happy to invite you Mr.{guests[0].title()}")
print(f"i am happy to invite you Mr.{guests[1].title()}")
print(f"i am happy to invite you Mr.{guests[2].title()}")
# Out:
# i am happy to invite you Mr.Ali
# i am happy to invite you Mr.Sami
# i am happy to invite you Mr.Ahmed

# %% [markdown]
# 3-5. Changing Guest List: You just heard that one of your guests can’t make the
# dinner, so you need to send out a new set of invitations. You’ll have to think of
# someone else to invite.
#
# •Start with your program from Exercise 3-4. Add a print() call at the end
# of your program stating the name of the guest who can’t make it.
#
# •Modify your list, replacing the name of the guest who can’t make it with
# the name of the new person you are inviting.
#
# •Print a second set of invitation messages, one for each person who is still
# in your list.

# %%
guests = ['ali', 'sami', 'ahmed']
cant_come = guests.pop()
print(f"Mr.{cant_come} can not come to dinner")
guests.append('qasim')
print('new List of invitations')
print(guests)
# Out:
# Mr.ahmed can not come to dinner
# new List of invitations
# ['ali', 'sami', 'qasim']

# %% [markdown]
# 3-6. More Guests: You just found a bigger dinner table, so now more space is
# available. Think of three more guests to invite to dinner.
#
# •Start with your program from Exercise 3-4 or Exercise 3-5. Add a print()
# call to the end of your program informing people that you found a bigger
# dinner table.
#
# •Use insert() to add one new guest to the beginning of your list.
#
# •Use insert() to add one new guest to the middle of your list.
#
# •Use append() to add one new guest to the end of your list.
#
# •Print a new set of invitation messages, one for each person in your list.

# %%
guests = ['ali', 'sami', 'ahmed']
guests.insert(0, 'qasim')
print(guests)
guests.insert(2,'zaid')
print(guests)
guests.append('bakar')
print(guests)
# for i in guests:
#   print(f"i want to u to invite on my dinner Mr.{i.title()}")

print(f"i wanna invite u on dinner Mr.{guests[-1].title()}")
print(f"i wanna invite u on dinner Mr.{guests[-2].title()}")
print(f"i wanna invite u on dinner Mr.{guests[-3].title()}")
print(f"i wanna invite u on dinner Mr.{guests[-4].title()}")
print(f"i wanna invite u on dinner Mr.{guests[-5].title()}")
print(f"i wanna invite u on dinner Mr.{guests[-6].title()}")
# Out:
# ['qasim', 'ali', 'sami', 'ahmed']
# ['qasim', 'ali', 'zaid', 'sami', 'ahmed']
# ['qasim', 'ali', 'zaid', 'sami', 'ahmed', 'bakar']
# i wanna invite u on dinner Mr.Bakar
# i wanna invite u on dinner Mr.Ahmed
# i wanna invite u on dinner Mr.Sami
# i wanna invite u on dinner Mr.Zaid
# i wanna invite u on dinner Mr.Ali
# i wanna invite u on dinner Mr.Qasim

# %% [markdown]
# 3-7. Shrinking Guest List: You just found out that your new dinner table won’t
# arrive in time for the dinner, and you have space for only two guests.
#
# •Start with your program from Exercise 3-6. Add a new line that prints a
# message saying that you can invite only two people for dinner.
#
# •Use pop() to remove guests from your list one at a time until only two
# names remain in your list. Each time you pop a name from your list, print
# a message to that person letting them know you’re sorry you can’t invite
# them to dinner.
#
# •Print a message to each of the two people still on your list, letting them
# know they’re still invited.
#
# •Use del to remove the last two names from your list, so you have an empty
# list. Print your list to make sure you actually have an empty list at the end
# of your program.

# %%
guests = ['qasim', 'ali', 'zaid', 'sami', 'ahmed', 'bakar']
drop_guest = guests.pop()
print(f"hi {drop_guest}!, sorry you are not invited.")
drop_guest = guests.pop()
print(f"hi {drop_guest}!, sorry you are not invited.")
drop_guest = guests.pop()
print(f"hi {drop_guest}!, sorry you are not invited.")
drop_guest = guests.pop()
print(f"hi {drop_guest}!, sorry you are not invited.")
print(f"hi {guests[0]} you are still invited")
print(f"hi {guests[1]} you are still invited")
print(guests)
del guests[0]
del guests[0]
print(guests)
# Out:
# hi bakar!, sorry you are not invited.
# hi ahmed!, sorry you are not invited.
# hi sami!, sorry you are not invited.
# hi zaid!, sorry you are not invited.
# hi qasim you are still invited
# hi ali you are still invited
# ['qasim', 'ali']
# []

# %% [markdown]
# ____

# %%
cars = ['bmw', 'audi', 'toyota', 'subaru']
#cars.sort()
#cars.sort(reverse=True)
# cars.reverse()
#len(cars)
#print(cars)

#print(sorted(cars))
#print(sorted(places, reverse=True))
# Out:
# 4

# %% [markdown]
# 3-8. Seeing the World: Think of at least five places in the world you’d like to
# visit.
#
# •Store the locations in a list. Make sure the list is not in alphabetical order.
#
# •Print your list in its original order. Don’t worry about printing the list neatly,
# just print it as a raw Python list.
#
# •Use sorted() to print your list in alphabetical order without modifying the
# actual list.
#
# •Show that your list is still in its original order by printing it.
#
# •Use sorted() to print your list in reverse alphabetical order without changing the order of the original list.
#
# •Show that your list is still in its original order by printing it again.
#
# •Use reverse() to change the order of your list. Print the list to show that its
# order has changed.
#
# •Use reverse() to change the order of your list again. Print the list to show
# it’s back to its original order.
#
# •Use sort() to change your list so it’s stored in alphabetical order. Print the
# list to show that its order has been changed.
#
# •Use sort() to change your list so it’s stored in reverse alphabetical order.
# Print the list to show that its order has changed.

# %%
places = ['baghdad', 'lahore', 'doha', 'london', 'riaz']
print(places)
print(sorted(places))
print(places)
print(sorted(places, reverse=True))
print(places)  # Show the original list is unchanged
places.reverse()
print(places)
places.reverse()
print(places)
places.sort()
print(places)
places.sort(reverse=True)
print(places)
# Out:
# ['baghdad', 'lahore', 'doha', 'london', 'riaz']
# ['baghdad', 'doha', 'lahore', 'london', 'riaz']
# ['baghdad', 'lahore', 'doha', 'london', 'riaz']
# ['riaz', 'london', 'lahore', 'doha', 'baghdad']
# ['baghdad', 'lahore', 'doha', 'london', 'riaz']
# ['riaz', 'london', 'doha', 'lahore', 'baghdad']
# ['baghdad', 'lahore', 'doha', 'london', 'riaz']
# ['baghdad', 'doha', 'lahore', 'london', 'riaz']
# ['riaz', 'london', 'lahore', 'doha', 'baghdad']

# %% [markdown]
# 3-9. Dinner Guests: Working with one of the programs from Exercises 3-4
# through 3-7 (page 42), use len() to print a message indicating the number
# of people you are inviting to dinner.

# %%
guests = ['ali', 'sami', 'ahmed']
len(guests)
# Out:
# 3

# %% [markdown]
# 3-11. Intentional Error: If you haven’t received an index error in one of your
# programs yet, try to make one happen. Change an index in one of your pro-
# grams to produce an index error. Make sure you correct the error before clos-
# ing the program.

# %%
guests = ['ali', 'sami', 'ahmed']

print(guests[3])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_1650/4019015872.py in <cell line: 0>()
#       1 guests = ['ali', 'sami', 'ahmed']
#       2
# ----> 3 print(guests[3])
#
# IndexError: list index out of range
