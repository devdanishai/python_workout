# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/chap008.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#greeter.py
def greet_user():
  print("hello!")

greet_user()
# Out:
# hello!

# %%
def greet_user(username):
    """Display a simple greeting."""
    print(f"Hello, {username.title()}!")

greet_user('jesse')
# Out:
# Hello, Jesse!

# %%
def greet_user(username):
  print(f'Hello, {username.title()}!')

greet_user('ali')
# Out:
# Hello, Ali!

# %% [markdown]
# 8-1. Message: Write a function called display_message() that prints one sen-
# tence telling everyone what you are learning about in this chapter. Call the
# function, and make sure the message displays correctly.

# %%
def message():
  print("i am learning Functions in python.")


message()
# Out:
# i am learning Functions in python.

# %% [markdown]
# 8-2. Favorite Book: Write a function called favorite_book() that accepts one
# parameter, title. The function should print a message, such as One of my
# favorite books is Alice in Wonderland. Call the function, making sure to
# include a book title as an argument in the function call.

# %%
def favourite_book(book_title):
  print(f"my favourite book is {book_title.title()}")

favourite_book('spiderman')
# Out:
# my favourite book is Spiderman

# %% [markdown]
# # Passing Arguments

# %% [markdown]
# ## 1. Positional Arguments

# %%
def animal_description(animal_type,animal_name):
  print(f"\nThe type of the animal is : {animal_name}")
  print(f"\nThe name of the animal is : {animal_name}")


animal_description('hamster','harry')
# Out:
# The type of the animal is : harry
#
# The name of the animal is : harry

# %% [markdown]
# #### 1.1 Multiple Function Calls

# %%
def animal_description(animal_type,animal_name):
  print(f"\nThe type of the animal is  {animal_type}")
  print(f"My pet name is  {animal_name}")


animal_description('hamster','harry')
animal_description('snake','cobra')
# Out:
# The type of the animal is  hamster
# My pet name is  harry
#
# The type of the animal is  snake
# My pet name is  cobra

# %% [markdown]
# ### 1.2 Order Matters in Positional Arguments

# %% [markdown]
# ## 2 Keyword Arguments

# %% [markdown]
# here we mention parameter names for arguments so mix up is not possible, like we can do in commented syntex.

# %%
def describe_pet(animal_type, pet_name):

    print(f"\nI have a {animal_type}.")
    print(f"My {animal_type}'s name is {pet_name.title()}.")

describe_pet(animal_type='hamster', pet_name='harry')
#describe_pet('harry','hamster')
# Out:
# I have a hamster.
# My hamster's name is Harry.

# %% [markdown]
# #### 2.1 Default Values

# %%
def describe_pet(pet_name, animal_type='dog'):
#Display information about a pet
  print(f"\nI have a {animal_type}.")
  print(f"My {animal_type}'s name is {pet_name.title()}.")
describe_pet('willie')
# Out:
# I have a dog.
# My dog's name is Willie.

# %% [markdown]
# #### 2.2 quivalent Function Calls

# %% [markdown]
# #### 2.3 Avoiding Argument Errors

# %% [markdown]
# ## Try it

# %% [markdown]
# 8-3. T-Shirt: Write a function called make_shirt() that accepts a size and the
# text of a message that should be printed on the shirt. The function should print
# a sentence summarizing the size of the shirt and the message printed on it.
# Call the function once using positional arguments to make a shirt. Call the
# function a second time using keyword arguments.

# %%
def T_shirt(size,message):
  print(f"\nsize of shirt is {size}")
  print(f"message on the shirt is : {message}")

T_shirt(38,'I Love NY')
T_shirt(size=32,message='never told anybody we came to los-vegas')
# Out:
# size of shirt is 38
# message on the shirt is : I Love NY
#
# size of shirt is 32
# message on the shirt is : never told anybody we came to los-vegas

# %% [markdown]
# ____

# %% [markdown]
# # Return Values

# %% [markdown]
# ## 1 Returning a Simple Value

# %%
def get_formatted_name(first_name, last_name):
  full_name = f"{first_name} {last_name}"
  return full_name.title()

musician = get_formatted_name('jimi', 'hendrix')
print(musician)
# Out:
# Jimi Hendrix

# %% [markdown]
# ## 2 Making an Argument Optional

# %%
def get_formatted_name(first_name, last_name, middle_name=''):
  full_name = f"{first_name} {middle_name} {last_name}"
  return full_name.title()

musician = get_formatted_name('john','hooker')
print(musician)
# Out:
# John  Hooker

# %% [markdown]
# ## 3 Returning a Dictionary

# %%
def build_person(first_name, last_name):
  person = {'first': first_name, 'last': last_name}
  return person

musician = build_person('jimi', 'hendrix')
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix'}

# %%
def build_person(first_name, last_name, age=None):
  person = {'first': first_name, 'last': last_name }
  if age:
    person['age'] = age
    return person

musician = build_person('jimi', 'hendrix', age = 27)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}

# %%
# def message_display(message):
#   print(message)


# message_display("how are you")
# Out:
# how are you

# %% [markdown]
# 8-2. Favorite Book: Write a function called favorite_book() that accepts one
# parameter, title. The function should print a message, such as One of my
# favorite books is Alice in Wonderland. Call the function, making sure to
# include a book title as an argument in the function call.

# %%
def fav_book(book_title):
  print(f"favourite book of mine is '{book_title}'")


fav_book("lords of rings")
# Out:
# favourite book of mine is 'lords of rings'

# %% [markdown]
# 8-3. T-Shirt: Write a function called make_shirt() that accepts a size and the
# text of a message that should be printed on the shirt. The function should print
# a sentence summarizing the size of the shirt and the message printed on it.
# Call the function once using positional arguments to make a shirt. Call the
# function a second time using keyword arguments.

# %%
def make_shirt(size,text):
  print(f"size of shirt is '{size}'.")
  print(f"text of shirt is '{text}'.")

make_shirt(42,"i love NY")
# Out:
# size of shirt is '42'.
# text of shirt is 'i love NY'.

# %%
def make_shirt(text, size='large'):
    print(f"size of shirt is '{size}'.")
    print(f"text of shirt is '{text}'.")

make_shirt("i love NY")
# Out:
# size of shirt is 'large'.
# text of shirt is 'i love NY'.

# %%
make_shirt(text='i lov python',size='small')
# Out:
# size of shirt is 'small'.
# text of shirt is 'i lov python'.

# %%
def make_shirt(size='large',text='I Lov Python'):
    print(f"size of shirt is '{size}'.")
    print(f"text of shirt is '{text}'.")

make_shirt()
make_shirt(size='medieum')
make_shirt(size='small')
# Out:
# size of shirt is 'large'.
# text of shirt is 'I Lov Python'.
# size of shirt is 'medieum'.
# text of shirt is 'I Lov Python'.
# size of shirt is 'small'.
# text of shirt is 'I Lov Python'.

# %% [markdown]
# 8-5. Cities: Write a function called describe_city() that accepts the name of
# a city and its country. The function should print a simple sentence, such as
# Reykjavik is in Iceland. Give the parameter for the country a default value.
# Call your function for three different cities, at least one of which is not in the
# default country.

# %%
def describe_city(city,country='Pakistan'):
  print(f"{city.title()} is in {country.title()}")


describe_city("Rawalpindi")
describe_city("ny","usa")
describe_city("Islamabad")
# Out:
# Rawalpindi is in Pakistan
# Ny is in Usa
# Islamabad is in Pakistan

# %%
def formatted_name(first_name,last_name):
  full_name = f"{first_name} {last_name}"
  return full_name.title()

formatted_name('ali', 'ahmed')
# Out:
# 'Ali Ahmed'

# %%
def formatted_name(first_name,last_name, middle_name=''):
  if middle_name:
    full_name = f"{first_name} {middle_name} {last_name}"
  else:
    full_name = f"{first_name} {last_name}"
  return full_name.title()

formatted_name('ali', 'ahmed', 'khan')
# Out:
# 'Ali Khan Ahmed'

# %%
def formatted_name(first_name,last_name):
  person = {'first': first_name, 'last' : last_name}
  return person

formatted_name('ali', 'wali')
# Out:
# {'first': 'ali', 'last': 'wali'}

# %%
def format_name(first_name,last_name):
  person = {'first' : first_name, 'last' : last_name }
  return person

format_name('ali', 'shah')
# Out:
# {'first': 'ali', 'last': 'shah'}

# %%
# it is infinite loop
def get_formatted_name(first_name,last_name):
  full_name = f"{first_name} {last_name}"
  return full_name

while True:
  print("Enter Your Full Name: ")
  f_name = input("Enter First Name: ")
  l_name = input("Enter Last Nsame: ")

  formatted_name = get_formatted_name(f_name, l_name)
  print(f"\nHello, {formatted_name}!")
# Out:
# Enter Your Full Name:
# Enter First Name: ali
# Enter Last Nsame: ahmed
#
# Hello, ali ahmed!
# Enter Your Full Name:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_925/2699711888.py in <cell line: 0>()
#       6 while True:
#       7   print("Enter Your Full Name: ")
# ----> 8   f_name = input("Enter First Name: ")
#       9   l_name = input("Enter Last Nsame: ")
#      10
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#    1175                 "raw_input was called, but this frontend does not support input requests."
#    1176             )
# -> 1177         return self._input_request(
#    1178             str(prompt),
#    1179             self._parent_ident["shell"],
#
# /usr/local/lib/python3.12/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
# ...

# %%
# it was infinite loop now have quit logic
def get_formatted_name(first_name,last_name):
  full_name = f"{first_name} {last_name}"
  return full_name

while True:
  print("Enter Your Full Name: ")
  print("enetr 'q' at anytime for exit ")

  f_name = input("Enter First Name: ")
  if f_name == 'q':
    print("bye!")
    break
  l_name = input("Enter Last Nsame: ")
  if l_name == 'q':
    print("bye!")
    break

  formatted_name = get_formatted_name(f_name, l_name)
  print(f"\nHello, {formatted_name}!")
# Out:
# Enter Your Full Name:
# enetr 'q' at anytime for exit
# Enter First Name: q
# bye!

# %%
def message():
  print('i am lerning Python')

message()
# Out:
# i am lerning Python

# %%
def fav_book(book_title):
  print(f'one of my favourite book is {book_title}')


fav_book('lords of rings')
# Out:
# one of my favourite book is lords of rings

# %% [markdown]
# - 8-3. T-Shirt: Write a function called make_shirt() that accepts a size and the
# text of a message that should be printed on the shirt. The function should print
# a sentence summarizing the size of the shirt and the message printed on it.
# Call the function once using positional arguments to make a shirt. Call the
# function a second time using keyword arguments.
#
# - 8-4. Large Shirts: Modify the make_shirt() function so that shirts are large
# by default with a message that reads I love Python. Make a large shirt and a
# medium shirt with the default message, and a shirt of any size with a different
# message.
#
# - 8-5. Cities: Write a function called describe_city() that accepts the name of
# a city and its country. The function should print a simple sentence, such as
# Reykjavik is in Iceland. Give the parameter for the country a default value.
# Call your function for three different cities, at least one of which is not in the
# default country.

# %%
def make_shirt(size,message):
  print(f"{size} is shirt size and '{message}' have to written on it")

make_shirt(32, 'i love NY')

make_shirt(size=36,message='i love Los Vegas')
# Out:
# 32 is shirt size and 'i love NY' have to written on it
# 36 is shirt size and 'i love Los Vegas' have to written on it

# %%
def make_shirt(size='Large',text="I Love Python"):
  print(f"{size} is shirt size and '{text}' have to written on it")

make_shirt()
make_shirt(size='medium')
make_shirt(size='small',text='i Love Js')
# Out:
# Large is shirt size and 'I Love Python' have to written on it
# medium is shirt size and 'I Love Python' have to written on it
# small is shirt size and 'i Love Js' have to written on it

# %%
def describe_city(city,country='USA'):
  print(f"{city} is in {country}")

describe_city(city='New York')
describe_city(city="Los Vegas")
describe_city(city="paris",country='France')
# Out:
# New York is in USA
# Los Vegas is in USA
# paris is in France

# %%
def get_formatted(f_name,l_name):
  full_nmae=f_name + ' ' + l_name
  return full_nmae.title()

player = get_formatted('ali','ahmed')
print(player)
# Out:
# Ali Ahmed

# %%
def build_person(f_name,l_name):
  person = {'first' : 'f_name', 'last' : 'l_name'}
  return person

player = build_person('waseem', 'akram')
print(player)
# Out:
# {'first': 'f_name', 'last': 'l_name'}

# %%
def build_person(first_name, last_name, age=''):
#Return a dictionary of information about a person
  person = {'first': first_name, 'last': last_name}
  if age:
    person['age'] = age
  return person

musician = build_person('jimi', 'hendrix', age=27)
print(musician)
# Out:
# {'first': 'jimi', 'last': 'hendrix', 'age': 27}

# %%
# def get_formatted_name(first_name, last_name):
#   full_name = first_name + ' ' + last_name
#   return full_name.title()
# # This is an infinite loop!
#   while True:
#     print("\nPlease tell me your name:")
#     f_name = input("First name: ")
#     l_name = input("Last name: ")

#   formatted_name = get_formatted_name(f_name, l_name)
#   print("\nHello, " + formatted_name + "!")

# %%
def get_formatted_name(first_name, last_name):
    full_name = first_name + ' ' + last_name
    return full_name.title()

while True:
    print("\nPlease tell me your name:")
    print("(enter 'q' at any time to quit)")

    f_name = input("First name: ")
    if f_name == 'q':
        break

    l_name = input("Last name: ")
    if l_name == 'q':
        break

    formatted_name = get_formatted_name(f_name, l_name)
    print(f"\nHello, {formatted_name}!")
# Out:
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: waseem
# Last name: akram
#
# Hello, Waseem Akram!
#
# Please tell me your name:
# (enter 'q' at any time to quit)
# First name: q

# %%
def get_formatted(first_name,last_name):
  full_name= first_name +  ' ' + last_name
  return full_name.title()

#get_formatted('ali','ahmed')
while True:
  f_name = input('First Name or "q" for exit: ')
  if f_name == 'q':
    break
  l_name = input('Last Name or "q" for exit: ')
  if l_name == 'q':
    break




  player_name = get_formatted(f_name,l_name)

  print(player_name)
# Out:
# First Name or "q" for exit: waseem
# Last Name or "q" for exit: akram
# Waseem Akram
# First Name or "q" for exit: q

# %% [markdown]
# 8-6. City Names: Write a function called city_country() that takes in the name
# of a city and its country. The function should return a string formatted like this:
#
# "Santiago, Chile"
#
# Call your function with at least three city-country pairs, and print the value
# that’s returned.

# %%
def city_country(city,country):
  print(f"{city.title()}, {country.title()}")


city_country('New York', 'USA')
# Out:
# New York, Usa

# %%
def city_country(city, country):
    return f"{city.title()}, {country.title()}"

print(city_country('New York', 'USA'))
print(city_country('Santiago', 'Chile'))
print(city_country('Paris', 'France'))
# Out:
# New York, Usa
# Santiago, Chile
# Paris, France

# %% [markdown]
# 8-7. Album: Write a function called make_album() that builds a dictionary
# describing a music album. The function should take in an artist name and an
# album title, and it should return a dictionary containing these two pieces of
# information. Use the function to make three dictionaries representing different
# albums. Print each return value to show that the dictionaries are storing the
# album information correctly.
# - Add an optional parameter to make_album() that allows you to store the
# number of tracks on an album. If the calling line includes a value for the num-
# ber of tracks, add that value to the album’s dictionary. Make at least one new
# function call that includes the number of tracks on an album.

# %%
def make_album(artist_name,album_title):
  album_directory = { 'name' : artist_name, 'title' : album_title}
  return album_directory


call = make_album('ali zafar', 'channo')
print(call)
# Out:
# {'name': 'ali zafar', 'title': 'channo'}

# %%
def make_album(artist_name, album_title, num_tracks=None):
    album_directory = {'name': artist_name, 'title': album_title}
    if num_tracks is not None:
        album_directory['num_tracks'] = num_tracks
    return album_directory

call1 = make_album('ali zafar', 'channo')
call2 = make_album('coldplay', 'a rush of blood to the head')
call3 = make_album('adele', '21', num_tracks=11)

print(call1)
print(call2)
print(call3)
# Out:
# {'name': 'ali zafar', 'title': 'channo'}
# {'name': 'coldplay', 'title': 'a rush of blood to the head'}
# {'name': 'adele', 'title': '21', 'num_tracks': 11}

# %% [markdown]
# 8-8. User Albums: Start with your program from Exercise 8-7. Write a while
# loop that allows users to enter an album’s artist and title.
#
#  Once you have that information, call make_album() with the user’s input and print the dictionary
# that’s created.
#
#
# Be sure to include a quit value in the while loop.

# %%
def make_album(name,title,tracks=None):
  album_dir = {'name' : name, 'title': title}
  if tracks is not None:
    album_dir['tracks']=tracks
  return album_dir

while True:
  n = input("enter name or q for quit: ")
  if n == 'q':
    break
  t = input("enter title or q for quit: ")
  if t == 'q':
    break

  album_info = make_album(n,t,tracks=20)
  print(album_info)
# Out:
# enter name or q for quit: 1
# enter title or q for quit: 2
# {'name': '1', 'title': '2', 'tracks': 20}
# enter name or q for quit: q

# %%
def make_album(name, title, tracks=None):
    album_dir = {'name': name, 'title': title}
    if tracks is not None:
        album_dir['tracks'] = tracks
    return album_dir

while True:
    n = input("Enter artist name or 'q' to quit: ")
    if n == 'q':
        break
    t = input("Enter album title or 'q' to quit: ")
    if t == 'q':
        break

    album_info = make_album(n, t)
    print(album_info)
# Out:
# Enter artist name or 'q' to quit: ali zafar
# Enter album title or 'q' to quit: channo
# {'name': 'ali zafar', 'title': 'channo'}
# Enter artist name or 'q' to quit: q

# %%
def greet_users(names):

  for name in names:
    msg = "Hello, " + name.title() + "!"
    print(msg)

usernames = ['hannah', 'ty', 'margot']
greet_users(usernames)
# Out:
# Hello, Hannah!
# Hello, Ty!
# Hello, Margot!

# %%
uncompleted_design = ['charger', 'case', 'data cable']
completed_models = []

# move each design to completed list
while uncompleted_design:
  current_design = uncompleted_design.pop()
  print('printed model: ' + current_design)
  completed_models.append(current_design)


print("\nThe following models have been printed:")
for i in completed_models:
  print(i)
# Out:
# printed model: data cable
# printed model: case
# printed model: charger
#
# The following models have been printed:
# data cable
# case
# charger

# %%
student_under_graduate = ['ali', 'sara', 'ahmed']
graduated_students = []

#move each student 1 by 1
while student_under_graduate:
  admit_student = student_under_graduate.pop()
  print(f"admit students are: {admit_student}")

# append admit students to graduated student list:
  graduated_students.append(admit_student)


#---print graduated students list---
print('\n ---graduated students list--- :')
for i in graduated_students:
  print(i)
# Out:
# admit students are: ahmed
# admit students are: sara
# admit students are: ali
#
#  ---print graduated students list--- :
# ahmed
# sara
# ali

# %%
def print_admit_students(student_under_graduate, graduated_students):
    while student_under_graduate:
        admit_student = student_under_graduate.pop()
        print(f"Admit student: {admit_student}")
        graduated_students.append(admit_student)

def show_graduated_students(graduated_students):
    print("\n--- Graduated Students ---")
    for student in graduated_students:
        print(student)

student_under_graduate = ['ali', 'sara', 'ahmed']
graduated_students = []

print_admit_students(student_under_graduate, graduated_students)
show_graduated_students(graduated_students)
# Out:
# Admit student: ahmed
# Admit student: sara
# Admit student: ali
#
# --- Graduated Students ---
# ahmed
# sara
# ali

# %%
def print_models(unprinted_designs, completed_models):
    """
    Simulate printing each design, until none are left.
    Move each design to completed_models after printing.
    """
    while unprinted_designs:
        # Pop from index 0 to print them in the order they are listed
        current_design = unprinted_designs.pop(0)

        # Simulate creating a 3D print from the design.
        print("Printing model: " + current_design)
        completed_models.append(current_design)

def show_completed_models(completed_models):
    """Show all the models that were printed."""
    print("\nThe following models have been printed:")
    for completed_model in completed_models:
        print(completed_model)

# Initialize the lists
unprinted_designs = ['iphone case', 'robot pendant', 'dodecahedron']
completed_models = []

# Run the functions
print_models(unprinted_designs, completed_models)
show_completed_models(completed_models)
# Out:
# Printing model: iphone case
# Printing model: robot pendant
# Printing model: dodecahedron
#
# The following models have been printed:
# iphone case
# robot pendant
# dodecahedron

# %%
pending_orders = ['Laptop', 'Phone', 'Tablet', 'Headphones']
shipped_orders = []


while pending_orders:
  inprocess_orders = pending_orders.pop()
  print(f"this is inprocess order: {inprocess_orders}")
  #apeend to shipped orders
  shipped_orders.append(inprocess_orders)


print("\nshipped orders list:")
for i in shipped_orders:
  print(i)
# Out:
# this is inprocess order: Headphones
# this is inprocess order: Tablet
# this is inprocess order: Phone
# this is inprocess order: Laptop
#
# shipped orders list:
# Headphones
# Tablet
# Phone
# Laptop

# %%
def show_pending_orders(pending_orders, shipped_orders):

  while pending_orders:
    inprocess_orders = pending_orders.pop()
    print(f"this is inprocess order: {inprocess_orders}")
    #apeend to shipped orders
    shipped_orders.append(inprocess_orders)

def show_shipped_orders(shipped_orders):
  print("\nshipped orders list:")
  for i in shipped_orders:
    print(i)


pending_orders = ['Laptop', 'Phone', 'Tablet', 'Headphones']
shipped_orders = []


show_pending_orders(pending_orders, shipped_orders)
show_shipped_orders(shipped_orders)
# Out:
# this is inprocess order: Headphones
# this is inprocess order: Tablet
# this is inprocess order: Phone
# this is inprocess order: Laptop
#
# shipped orders list:
# Headphones
# Tablet
# Phone
# Laptop

# %%
favorite_fruits = ['apple', 'banana', 'mango', 'orange']

while True:
  if favorite_fruits == 'apple' or favorite_fruits == 'mango':
    print("i like these")
  else:
    print("i do not like them")
    break
# Out:
# i do not like them

# %%
favorite_fruits = ['apple', 'banana', 'mango', 'orange']

for i in favorite_fruits:
  if i == 'apple':
    print('i like apples')
  elif i == 'mango':
    print('i like mangoes')
  else:
    print("i do not like this fruit")
# Out:
# i like apples
# i do not like this fruit
# i like mangoes
# i do not like this fruit

# %%
def print_fav_fruit(favorite_fruits):

  for i in favorite_fruits:
    if i == 'apple':
      print('i like apples')
    elif i == 'mango':
      print('i like mangoes')
    else:
      print("i do not like this fruit")

favorite_fruits = ['apple', 'banana', 'mango', 'orange']

print_fav_fruit(favorite_fruits)
# Out:
# i like apples
# i do not like this fruit
# i like mangoes
# i do not like this fruit

# %%
pets = {
    'ali': 'cat',
    'sara': 'parrot',
    'ahmed': 'dog',
    'ayesha': 'rabbit'
}

for k,v in pets.items():
  print(f"{k} owns a {v}")
# Out:
# ali owns a cat
# sara owns a parrot
# ahmed owns a dog
# ayesha owns a rabbit

# %%
def print_pet_owner(pets):
  for k,v in pets.items():
    print(f"{k} owns a {v}")


pets = {
    'ali': 'cat',
    'sara': 'parrot',
    'ahmed': 'dog',
    'ayesha': 'rabbit'
}

print_pet_owner(pets)
# Out:
# ali owns a cat
# sara owns a parrot
# ahmed owns a dog
# ayesha owns a rabbit

# %%
students = ['ali','sara','ahmed', 'dawood']

copy = students[:]
copy1 = students.copy()
print(students)
print(copy)
print(copy1)
# Out:
# ['ali', 'sara', 'ahmed', 'dawood']
# ['ali', 'sara', 'ahmed', 'dawood']
# ['ali', 'sara', 'ahmed', 'dawood']

# %% [markdown]
# 8-9. Magicians: Make a list of magician’s names. Pass the list to a function
# called show_magicians(), which prints the name of each magician in the list.

# %%
magicians = ['ali', 'saad', 'sara', 'hamza']

for i in magicians:
  print(i)
# Out:
# ali
# saad
# sara
# hamza

# %%
def show_magician(names):

  for i in names:
    print(i)

magicians = ['ali', 'saad', 'sara', 'hamza']


print_names(magicians)
# Out:
# ali
# saad
# sara
# hamza

# %% [markdown]
# 8-10. Great Magicians: Start with a copy of your program from Exercise 8-9.
# Write a function called make_great() that modifies the list of magicians by add-
# ing the phrase the Great to each magician’s name. Call show_magicians() to
# see that the list has actually been modified

# %%
def make_great(magicians):
    """Add 'Great' to each magician's name."""
    for i in range(len(magicians)):
        magicians[i] = "Great " + magicians[i]


def show_magicians(magicians):
    """Display each magician's name."""
    for magician in magicians:
        print(magician)


magicians = ['ali', 'saad', 'sara', 'hamza']

make_great(magicians)
show_magicians(magicians)
# Out:
# Great ali
# Great saad
# Great sara
# Great hamza

# %%
magicians = ['ali', 'saad', 'sara', 'hamza']
print(magicians)

for i in range(len(magicians)):
  magicians[i] = "Great " + magicians[i]

print(magicians)
# Out:
# ['ali', 'saad', 'sara', 'hamza']
# ['Great ali', 'Great saad', 'Great sara', 'Great hamza']

# %% [markdown]
# 8-11. Unchanged Magicians: Start with your work from Exercise 8-10. Call the
# function make_great() with a copy of the list of magicians’ names. Because the
# original list will be unchanged, return the new list and store it in a separate list.
# Call show_magicians() with each list to show that you have one list of the origi-
# nal names and one list with the Great added to each magician’s name.

# %%
magicians = ['ali', 'saad', 'sara', 'hamza']

# Make a copy of the original list
great_magicians = magicians[:]

# Add "Great" to each name in the copied list
for i in range(len(great_magicians)):
    great_magicians[i] = "Great " + great_magicians[i]

print("Original list:")
for magician in magicians:
    print(magician)

print("\nGreat magicians:")
for magician in great_magicians:
    print(magician)
# Out:
# Original list:
# ali
# saad
# sara
# hamza
#
# Great magicians:
# Great ali
# Great saad
# Great sara
# Great hamza

# %%
def make_great(magicians):
    """Return a new list with 'Great' added to each name."""
    great_magicians = []

    while magicians:
        magician = magicians.pop(0)
        great_magicians.append("Great " + magician)

    return great_magicians


def show_magicians(magicians):
    """Display each magician."""
    for magician in magicians:
        print(magician)


magicians = ['ali', 'saad', 'sara', 'hamza']

# Pass a copy, not the original
great_magicians = make_great(magicians[:])

print("Original list:")
show_magicians(magicians)

print("\nGreat magicians:")
show_magicians(great_magicians)
# Out:
# Original list:
# ali
# saad
# sara
# hamza
#
# Great magicians:
# Great ali
# Great saad
# Great sara
# Great hamza

# %%
def make_pizza(*toppings):
  print(toppings)


make_pizza('cheese')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# ('cheese',)
# ('mushrooms', 'green peppers', 'extra cheese')

# %%
x = 5
y = 6
summy = x+y
print(summy)
# Out:
# 11

# %%
def sumy(*num):
  return sum(num)

sum1=sumy(5,6,7)
print(sum1)
# Out:
# 18

# %%
total = 0
n = 1

while n <= 5:
  total=total+n
  print(n)
  n = n+ 1

print(total)
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
def sumi(*n):
  total = 0

  for i in n:
    total+=i
  return total

sum1 = sumi(4,5,6)
print(sum1)
# Out:
# 15

# %%
n = int(input("enter some number with ',': "))
num = n.split(,)

total = 0

for i in n:
  total = total+i


print(total)
# Out:
# enter some number with ',': 4,5,6
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_485/2584467409.py in <cell line: 0>()
# ----> 1 n = int(input("enter some number with ',': "))
#       2 total = 0
#       3
#       4 for i in n:
#       5   total = total+i
#
# ValueError: invalid literal for int() with base 10: '4,5,6'

# %%
n = input("Enter numbers separated by commas: ")
num = n.split(",")
print(num)

total = 0

for i in num:
    total += int(i)

print(total)
# Out:
# Enter numbers separated by commas: 4,5,6
# ['4', '5', '6']
# 15

# %%
n = input("enter numbers seperated by commas: ")
num = n.split(",")
num = int(num)
print(num)
total = 0

for i in num:
  total = total + i

print(total)
# Out:
# enter numbers seperated by commas: 4,5,6
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_485/374896405.py in <cell line: 0>()
#       1 n = input("enter numbers seperated by commas: ")
#       2 num = n.split(",")
# ----> 3 num = int(num)
#       4 print(num)
#       5 total = 0
#
# TypeError: int() argument must be a string, a bytes-like object or a real number, not 'list'

# %%
num = []

while True:
  usr_inp = input("enter num or 'q': ")
  if usr_inp == 'q':
    break
  else:
    num.append(int(usr_inp))


print(num)
# Out:
# enter num or 'q': 4
# enter num or 'q': 5
# enter num or 'q': 6
# enter num or 'q': q
# [4, 5, 6]

# %%
num = []

while True:
    usr_inp = input("Enter a number or 'q': ")

    if usr_inp == 'q':
        break
    else:
        num.append(int(usr_inp))

print(num)
total = 0
for i in num:
  total = total + i

print(total)
# Out:
# Enter a number or 'q': 4
# Enter a number or 'q': 5
# Enter a number or 'q': 6
# Enter a number or 'q': q
# [4, 5, 6]
# 15

# %%
def make_pizza(*toppings):
#"""Summarize the pizza we are about to make."""
  print("\nMaking a pizza with the following toppings:")

  for topping in toppings:
    print("- " + topping)

make_pizza('pepperoni')
make_pizza('mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a pizza with the following toppings:
# - pepperoni
#
# Making a pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
def make_pizza(size, *toppings):
#"""Summarize the pizza we are about to make."""
  print("\nMaking a " + str(size) + "-inch pizza with the following toppings:")
  for topping in toppings:
    print("- " + topping)
make_pizza(16, 'pepperoni')
make_pizza(12, 'mushrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 16-inch pizza with the following toppings:
# - pepperoni
#
# Making a 12-inch pizza with the following toppings:
# - mushrooms
# - green peppers
# - extra cheese

# %%
# making a function with mix positional and arbitary arguments

def make_pizza(size,*toppings):
  print("\nMaking a " + str(size) + "-inch pizza with the following toppings:")
  for i in toppings:
    print("- " + i)

make_pizza(16, 'pepperoni')
make_pizza(12, 'mashrooms', 'green peppers', 'extra cheese')
# Out:
# Making a 16-inch pizza with the following toppings:
# - pepperoni
#
# Making a 12-inch pizza with the following toppings:
# - mashrooms
# - green peppers
# - extra cheese

# %%
def build_profile(first, last, **user_info):
    """Build a dictionary containing everything we know about a user."""
    profile = {}
    profile['first_name'] = first
    profile['last_name'] = last

    for key, value in user_info.items():
        profile[key] = value

    return profile

user_profile = build_profile('albert', 'einstein',
                             location='princeton',
                             field='physics')

print(user_profile)
# Out:
# {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'field': 'physics'}
# {'first_name': 'will', 'last_name': 'smith', 'location': 'hollywood', 'profession': 'actor'}

# %%
# *args example
def fun(*args):
    return sum(args)

print(fun(5, 10, 15))

# **kwargs example
def fun(**kwargs):
    for k, val in kwargs.items():
        print(k, val)

fun(a=1, b=2, c=3)
# Out:
# 30
# a 1
# b 2
# c 3

# %%
def student(**kwargs):
    for k, v in kwargs.items():
        print(k, v)

stu = student(name="Ali", grade=9, subject="Science")
print(stu)
# Out:
# name Ali
# grade 9
# subject Science
# None

# %%
def student(**kwargs):
    for k, v in kwargs.items():
        return k, v

stu = student(name="Ali", grade=9, subject="Science")
print(stu)
# Out:
# ('name', 'Ali')

# %%
def student(**kwargs):
    return kwargs

stu = student(name="Ali", grade=9, subject="Science")
print(stu)
# Out:
# {'name': 'Ali', 'grade': 9, 'subject': 'Science'}

# %%
def dict1(**kwargs):
  return kwargs

show= dict1(a=1,b=2,c=3,d=4)
print(show)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# ## nested dict

# %%
def student(**kwargs):
    return kwargs

info = student(
    name="Ali",
    age=20,
    address={
        "city": "Lahore",
        "country": "Pakistan"
    }
)

print(info)
# Out:
# {'name': 'Ali', 'age': 20, 'address': {'city': 'Lahore', 'country': 'Pakistan'}}

# %%
def student(first,last,**info):
  student_data= {}
  student_data['first_name'] = first
  student_data['last_name'] = last
  for k,v in info.items():
    student_data[k]=v
  return student_data


s_data = student('albert', 'einstein',location='princeton',field='physics')
print(s_data)
# Out:
# {'first_name': 'albert', 'last_name': 'einstein', 'location': 'princeton', 'field': 'physics'}

# %% [markdown]
# 8-12. Sandwiches: Write a function that accepts a list of items a person wants
# on a sandwich.
#
# The function should have one parameter that collects as many
# items as the function call provides, and it should print a summary of the sand-
# wich that is being ordered. Call the function three times, using a different number of arguments each time.

# %%
def make_sandwich(*args):
  print("\nThis sandwich has following items:")
  for i in args:
    print(f"- {i}")


make_sandwich('chicken','cheese','patty','tomato','ketchup')
make_sandwich("potato","mayo","carrot")
make_sandwich("chicken","salad")
# Out:
# This sandwich has following items:
# - chicken
# - cheese
# - patty
# - tomato
# - ketchup
#
# This sandwich has following items:
# - potato
# - mayo
# - carrot
#
# This sandwich has following items:
# - chicken
# - salad

# %% [markdown]
# 8-13. User Profile: Start with a copy of user_profile.py from page 153. Build
# a profile of yourself by calling build_profile(), using your first and last names
# and three other key-value pairs that describe you.

# %%
def build_profile(first,last,**kwargs):
  profile={}
  profile['first_name']=first
  profile['last_name']=last
  for k,v in kwargs.items():
    profile[k]=v
  return profile

my_info = build_profile('ali','ahmed',edu='Bsc',location='ISB',status='married')
print(my_info)
# Out:
# {'first_name': 'ali', 'last_name': 'ahmed', 'edu': 'Bsc', 'location': 'ISB', 'status': 'married'}

# %% [markdown]
# 8-14. Cars: Write a function that stores information about a car in a diction-
# ary. The function should always receive a manufacturer and a model name. It
# should then accept an arbitrary number of keyword arguments. Call the func-
# tion with the required information and two other name-value pairs, such as a
# color or an optional feature. Your function should work for a call like this one:
# ___
# car = make_car('subaru', 'outback', color='blue', tow_package=True)
# ___
# Print the dictionary that’s returned to make sure all the information was
# stored correctly.

# %%
def car_info(name,manufacturer,**info):
  details={}
  details['name_car'] = name
  details['car_maker'] = manufacturer
  for k,v in info.items():
    details[k]=v
  return details

car_information = car_info('alto','suzuki', seat_is_4=True,color='white')
print(car_information)
# Out:
# {'name_car': 'alto', 'car_maker': 'suzuki', 'seat_is_4': True, 'color': 'white'}

# %%
def car_info(name, manufacturer, **info):
    details = {}

    details['name_car'] = name
    details['name_maker'] = manufacturer

    for k, v in info.items():
        details[k] = v

    return details


car_information = car_info(
    'alto',
    'suzuki',
    seat_is_4=True,
    color='white'
)

print(car_information)
# Out:
# {'name_car': 'alto', 'name_maker': 'suzuki', 'seat_is_4': True, 'color': 'white'}
