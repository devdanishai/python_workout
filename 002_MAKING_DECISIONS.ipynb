# %% [markdown]
# <a href="https://colab.research.google.com/github/devdanishai/python_workout/blob/main/002_MAKING_DECISIONS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ccc19j1
apple = int(input())*3 + int(input())*2 + int(input())*1
banana = int(input())*3 + int(input())*2 + int(input())*1

if apple > banana:
    print("A")
elif apple < banana:
    print("B")
else:
    print("T")
# Out:
# 10
# 3
# 7
# 8
# 9
# 6
# B

# %%
# ccc18j1

first = int(input())
second = int(input())
third = int(input())
fourth = int(input())

if (first == 8 or first == 9) and second == third and (fourth == 8 or fourth == 9):
    print("ignore")
else:
    print("answer")
# Out:
# 8
# 2
# 2
# 3
# answer

# %%
# 1. DMOJ problem ccc06j1, Canadian Calorie Counting
calories = 0
order = []
while True:
  print("1. burger")
  print("2. drinks")
  print("3. side item")
  print("4. dessert")

  choice = input("enter your choice:")

  if choice == '1':
    ask = input(
        "1 – Cheeseburger (461 Calories)"
        "2 – Fish Burger (431 Calories)"
        "3 – Veggie Burger (420 Calories)"
        "4 – no burger"

    )
    if ask == "1":
      calories += 461
      order.append('cheeseburger')
      print("cheeseburger added")
    elif ask == '2':
      calories += 431
      order.append('fish burger')
      print("fish burger added")
    elif ask == '3':
      calories += 420
      order.append('veggie burger')
    elif ask == '4':
      calories += 0
      order.append('no burger')
    else:
      print("invalid input")

# %%
# ccc06j1
burger = input()
side_item = input()
drinks = input()
dessert = input()

calories = 0

if burger == '1':
    calories += 461
elif burger == '2':
    calories += 431
elif burger == '3':
    calories += 420
elif burger == '4':
    calories += 0

if side_item == '1':
    calories += 100
elif side_item == '2':
    calories += 57
elif side_item == '3':
    calories += 70
elif side_item == '4':
    calories += 0

if drinks == '1':
    calories += 130
elif drinks == '2':
    calories += 160
elif drinks == '3':
    calories += 118
elif drinks == '4':
    calories += 0

if dessert == '1':
    calories += 167
elif dessert == '2':
    calories += 266
elif dessert == '3':
    calories += 75
elif dessert == '4':
    calories += 0

print(calories)
# Out:
# 1
#
# 2
# 2
# 887

# %%
# 2. DMOJ problem ccc15j1, Special Day
# ccc15j1
month = int(input())
day = int(input())

if month < 2 or (month == 2 and day < 18):
    print("Before")
elif month == 2 and day == 18:
    print("Special")
else:
    print("After")
# Out:
# 2
# 18
# Special

# %%
month = int(input())
day = int(input())

if month < 2 and ( month == 2 and day < 18):
  print("before")
elif month == 2 and day == 18:
  print('special')
else:
  print("after")
# Out:
# 3
# 18
# after

# %%
# ccc15j1
from datetime import date

month = int(input())
day = int(input())

given_date = date(2015, month, day)
special_date = date(2015, 2, 18)

if given_date < special_date:
    print("Before")
elif given_date == special_date:
    print("Special")
else:
    print("After")
# Out:
# 2
# 18
# Special

# %%
from datetime import date

print(date.today())
# Out:
# 2026-08-13

# %%
import time

print(time.time())
# Out:
# 1786618259.6084657

# %%
from datetime import datetime

now = datetime.now()
print(now)
# Out:
# 2026-08-13 10:54:30.373873

# %%
# DMOJ problem ccc15j2, Happy or Sad

# %%
line = input()

happy = line.count(":-)")
sad = line.count(":-(")

if happy == 0 and sad == 0:
    print("none")
elif happy == sad:
    print("unsure")
elif happy > sad:
    print("happy")
else:
    print("sad")
# Out:
# How are you :-) doing :-( today :-)?
# happy

# %%
line = input()

happy = line.count(":-)")
sad = line.count(":-(")

if happy == 0 and sad == 0:
    print("none")
elif happy == sad:
    print("unsure")
elif happy > sad:
    print("happy")
else:
    print("sad")
# Out:
# :-), :-)
# happy

# %%
# 4. DMOJ problem dmopc16c1p0, C.C. and Cheese-kun
w = int(input())
c = int(input())

if w == 3 and c >= 95:
  print("C.C. is absolutely satisfied with her pizza.")
elif w == 1 and c <= 50:
  print("C.C. is fairly satisfied with her pizza.")
else:
  print("C.C. is very satisfied with her pizza.")
# Out:
# 2
# 70
# C.C. is very satisfied with her pizza.

# %%
# DMOJ problem ccc07j1, Who is in the Middle
a = int(input())
b = int(input())
c = int(input())
list1 = []
list1.append(a)
list1.append(b)
list1.append(c)
list1.sort()
print(list1[1])
# Out:
# 8
# 5
# 8
# 8
